# %%
# %pylab inline
import seaborn as sns
import pandas as pd
import glob
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
PLOTDIR = '/storage/BonnieH/selection_project/joint_method/figures/validation_one_opt/plot_together/'
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def beautify_fig(fig_num):
    plt.figure(fig_num, figsize=(12, 6))
    
    plt.xticks(rotation = 35)
    plt.axvline(x=2.5, linestyle = '--',c='black')
    plt.axvline(x=5.5, linestyle = '--',c='black')
    plt.axvline(x=8.5, linestyle = '--',c='black')
    plt.text(0.2,10**-7.3,'Mean s=' + r'$10^{-5}$')
    plt.text(3.2,10**-7.3,'Mean s=' + r'$10^{-4}$')
    plt.text(6.2,10**-7.3,'Mean s=' + r'$10^{-3}$')
    plt.text(9.2,10**-7.3,'Mean s=' + r'$10^{-2}$')
    plt.xlabel("Ground truth a,b", labelpad=20)

# %%
# PLot validation of each optimal allele in a period together

def main():
    
    means = [10**-5, 10**-4, 10**-3, 10**-2] 
    pers = [2,3,4]
    opt_dic = {}
    opt_dic[2] = [11,14,17,20]
    opt_dic[3] = [5,6,7,8,10,13]
    opt_dic[4] = [7,8,9,10]
    
    folder = 't35'
    fig_num = 0
    
    for per in pers:
        
        fig_num = fig_num + 1
        dic = {}
        dic['Optimal allele'] = []
        dic['Ground truth a,b'] = []
        dic['Estimated mean s'] = []
        dic['Estimated a'] = []
        dic['Estimated b'] = []
        for opt in opt_dic[per]:
            
            for mean in means:
                
                for j in range(0,3):

                    file_list = glob.glob('./results/validation_multiple_one_opt/%s/per_%d_opt_%d_*_%.5f.txt'%(folder, per, opt, mean)) 
                    file_list.sort()
                       
                    filename = file_list[j]
                        
                    allele_freqs_file = open(filename, 'r')
                    lines = allele_freqs_file.readlines()

                    
                    line = lines[1]
                    info = line.strip().split(' ')
                    k = float(info[7])
                    theta = float(info[10])
                    
                    line = lines[6]       
                    info = line.strip().split(': ')
                    
                    params = info[1]
                    params = params.strip().split('), ')
                    
                    i = 0
                    for param in params:
                        i = i + 1
                        param = param[1:]
                        if param[-1] == ')':
                            param = param[:-1]
                        param = param.strip().split(', ')
                        #print(param)
                        
                        dic['Optimal allele'].append(opt)
                        dic['Estimated mean s'].append(float(param[0]))
                        dic['Ground truth a,b'].append('(%.1E,%.1E)'%(k,theta))
                        dic['Estimated a'].append(float(param[1]))
                        dic['Estimated b'].append(float(param[2]))
        
        df = pd.DataFrame(data=dic)
        
        # Plot estimated mean s
        plt.figure(fig_num, figsize=(12, 6))
        sns.swarmplot(x="Ground truth a,b", y="Estimated mean s", hue="Optimal allele", data=df)
        plt.yscale('log')
        plt.ylim(10**-6, 0.1)
        plt.title('Joint method validation of estimated mean s: Period %d'%(per))
        beautify_fig(fig_num)
        #plt.savefig(PLOTDIR + '%s/per_%d.pdf'%(folder, per),bbox_inches='tight')
        
        # Plot estimated a (shape parameter)
        fig_num = fig_num + 1
        plt.figure(fig_num, figsize=(12, 6))
        sns.swarmplot(x="Ground truth a,b", y="Estimated a", hue="Optimal allele", data=df)
        plt.ylim(0,1)
        plt.title('Joint method validation of estimated a (shape parameter): Period %d'%(per))
        beautify_fig(fig_num)
        
        # Plot estimated b (scale parameter)
        fig_num = fig_num + 1
        plt.figure(fig_num, figsize=(12, 6))
        sns.swarmplot(x="Ground truth a,b", y="Estimated b", hue="Optimal allele", data=df)
        plt.yscale('log')
        plt.ylim(10**-6,0.1)
        plt.title('Joint method validation of estimated b (scale parameter): Period %d'%(per))
        beautify_fig(fig_num)
        
        print('Finished plotting period %d'%(per))

# %%
# %%time
if __name__ == '__main__':
    main()
# Out:
# Finished plotting period 2
# Finished plotting period 3
# Finished plotting period 4
# CPU times: user 14.7 s, sys: 11.9 ms, total: 14.7 s
# Wall time: 14.7 s
