# %%
import numpy as np

means = [10**-5, 10**-4, 10**-3, 10**-2]
pers = [2, 3, 4]
cutoffs = {}
cutoffs[2] = 11
cutoffs[3] = 8
cutoffs[4] = 7
for mean in means:
    for per in pers:
        for i in range(0, 3):
            k = np.random.uniform() #0,0.4
            theta = mean/k
            #print('nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py %d 6 0.0 %d euro_p2 18 18 18 18 18 18 10000 wide_prior 0 0 %.6f %.6f %.5f &\n'%(per, cutoffs[per], k, theta, mean))
            print('nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py %d euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 %.6f %.6f %.5f &\n'%(per, k, theta, mean))
            #print(str(round(k, 5)) + ' ' + str(round(theta, 5)))
# Out:
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py 2 euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 0.013831 0.000723 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py 2 euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 0.514216 0.000019 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py 2 euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 0.834884 0.000012 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py 3 euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 0.669187 0.000015 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py 3 euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 0.016335 0.000612 0.00001 &
#
# ...
