# %%
import numpy as np

means = [10**-5, 10**-4, 10**-3, 10**-2]
pers = [2, 3, 4]
cutoffs = {}
cutoffs[2] = 11
cutoffs[3] = 8
cutoffs[4] = 7
for mean in means:
    
    for i in range(0, 3):
        k = np.random.uniform() #0,0.4
        theta = mean/k
        for per in pers:
            print('nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py %d 6 0.0 %d euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 %.6f %.6f %.5f &\n'%(per, cutoffs[per], k, theta, mean))
            #print('nohup time python /storage/BonnieH/selection_project/joint_method/joint_method_validation_mult.py %d euro_p2 18 18 18 18 18 18 10000 200 fig2c 0 %.6f %.6f %.5f &\n'%(per, k, theta, mean))
            #print(str(round(k, 5)) + ' ' + str(round(theta, 5)))
# Out:
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.460816 0.000022 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.460816 0.000022 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.460816 0.000022 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.478010 0.000021 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.478010 0.000021 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.478010 0.000021 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.196640 0.000051 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.196640 0.000051 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.196640 0.000051 0.00001 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.317893 0.000315 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.317893 0.000315 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.317893 0.000315 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.898568 0.000111 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.898568 0.000111 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.898568 0.000111 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.138750 0.000721 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.138750 0.000721 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.138750 0.000721 0.00010 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.903996 0.001106 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.903996 0.001106 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.903996 0.001106 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.205620 0.004863 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.205620 0.004863 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.205620 0.004863 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.649175 0.001540 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.649175 0.001540 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.649175 0.001540 0.00100 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.779042 0.012836 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.779042 0.012836 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.779042 0.012836 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.300364 0.033293 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.300364 0.033293 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.300364 0.033293 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 2 6 0.0 11 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.003954 2.528959 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 3 6 0.0 8 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.003954 2.528959 0.01000 &
#
# nohup time python /storage/BonnieH/selection_project/joint_method/joint_method.py 4 6 0.0 7 euro_p2 18 18 18 18 18 18 10000 single_sim 0 0 0.003954 2.528959 0.01000 &
